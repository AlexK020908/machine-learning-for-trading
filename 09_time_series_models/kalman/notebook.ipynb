# %% [markdown]
# # kalman filter
# - use kalman filter in any place when you have uncertain information about a dynamic system, you can make an educated guess on what the system is going to do next.
# - ideal for systems that are continuously changing
#
# ## Problem Formation
# suppose you built a robot and need to know the exact positions of it in the wild. Even though it gives GPS measurements, they are accurate to about 10 meters, which is good but not good enough. Suppose we keep track of states x = [p, v] where p is position and v is velocity

# %%
https://www.bzarg.com/p/how-a-kalman-filter-works-in-pictures/
